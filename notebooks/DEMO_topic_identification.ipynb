# %% [markdown]
# ## Topic identification
#
# This notebook demonstrates how users can use PFD Toolkit to identify recurring topics or themes from PFD reports.

# %% [markdown]
# ### Set up
#
# We first need to load in a sample of reports, an initalise our `LLM` and `Extractor` Classes.

# %%
from pfd_toolkit import load_reports, Extractor, LLM
from dotenv import load_dotenv
import os

# Load reports
reports = load_reports(n_reports=100)

# Set up LLM client
load_dotenv("api.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

llm_client = LLM(api_key=openai_api_key, max_workers=40)

# Set up Extractor
extractor = Extractor(
    llm=llm_client,
    reports=reports
)

# %% [markdown]
# ### Summarise reports
#
# Since we'll be feeding our reports to our LLM in one big prompt (rather than taking it one row at a time), it's a good idea to first summarise the reports into a short paragraph with all the main points.
#
# Running the `.summarise()` method produces a new column, which gets added to `self.reports`.

# %%
# Summarise reports
extractor.summarise(trim_intensity="medium")
# Out:
# Summarising reports:   0%|          | 0/100 [00:00<?, ?it/s]INFO:backoff:Backing off _call_llm(...) for 0.1s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.8s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.5s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.3s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.3s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.9s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.4s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.7s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.1s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.9s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.5s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.8s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.4s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.0s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.7s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.3s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.6s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.1s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.8s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 1.0s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.0s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.9s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.0s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.3s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.6s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.3s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.4s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.1s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.4s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.1s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.9s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.8s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 1.0s (openai.APIConnectionError: Connection error.)
# INFO:backoff:Backing off _call_llm(...) for 0.2s (openai.APIConnectionError: Connection error.)
#                                                   URL         ID       Date  \
# 0   https://www.judiciary.uk/prevention-of-future-...  2025-0248 2025-05-28
# 1   https://www.judiciary.uk/prevention-of-future-...  2025-0243 2025-05-27
# 2   https://www.judiciary.uk/prevention-of-future-...  2025-0244 2025-05-27
# 3   https://www.judiciary.uk/prevention-of-future-...  2025-0245 2025-05-27
# 4   https://www.judiciary.uk/prevention-of-future-...  2025-0246 2025-05-27
# ..                                                ...        ...        ...
# 95  https://www.judiciary.uk/prevention-of-future-...  2025-0152 2025-03-18
# 96  https://www.judiciary.uk/prevention-of-future-...  2025-0149 2025-03-18
# 97  https://www.judiciary.uk/prevention-of-future-...  2025-0144 2025-03-17
# 98  https://www.judiciary.uk/prevention-of-future-...  2025-0145 2025-03-17
# 99  https://www.judiciary.uk/prevention-of-future-...  2025-0146 2025-03-17
#
#             CoronerName                            Area  \
# 0          Clare Bailey         Teesside and Hartlepool
# 1        Andrew Cousins               Blackpool & Fylde
# 2        Peter Merchant             West Yorkshire West
# 3         Nadia Persaud                     East London
# 4        Rebecca Sutton           Durham and Darlington
# ..                  ...                             ...
# 95       Joanne Andrews  West Sussex, Brighton and Hove
# 96  Andrew Hetherington                  Northumberland
# 97        Sean Horstead                           Essex
# 98        Rachel Knight             South Wales Central
# 99         Mary Hassell              Inner North London
#
#                                              Receiver  \
# 0   1 Department of Health and Social Care 2 Chief...
# 1                     BARCHESTER HEALTHCARE LIMITED 1
# 2         1 , Chief Constable West Yorkshire Police 1
# 3   , Chief Executive Officer, Barts Health NHS Fo...
# 4   1. Deputy Chief Constable , Durham Constabular...
# ..                                                ...
# 95  1. The President of the Royal College of Obste...
# 96  CHIEF EXECUTIVE, NORTHUMBRIA HEALTHCARE NHS FO...
# 97  1. Chief Executive Officer of Essex Partnershi...
# 98  The Chief Executive Cardiff & Vale University ...
# 99  1. Medical Director Royal Free Hospital Pond S...
#
#                               InvestigationAndInquest  \
# 0   Mr Dean Bradley died on 15 th October 2021 at ...
# 1   On 30 April 2025 and 23 May 2025, at an inques...
# 2   On 15 February 2024 the death of Paul Andrew A...
# 3   On the 13 June 2024 I commenced an investigati...
# 4   On 7 January 2025 an investigation into the de...
# ..                                                ...
# 95  On 3 October 2023 I commenced an investigation...
# 96  On 1 May 2024 I commenced an investigation int...
# 97  On 31 st October 2023 I commenced an investiga...
# 98  On 24 October 2023 I commenced an investigatio...
# 99  On 17 September 2024 one of my assistant coron...
#
#                                  CircumstancesOfDeath  \
# 0   At approximately 0300 on 15 th October 2021 Mr...
# 1   I returned the following in box 4 of the Recor...
# 2   As identified above, Paul Alexander had a long...
# 3   Abdirahman Afrah began to suffer from chest pa...
# 4   The Deceased had a long history of mental heal...
# ..                                                ...
# 95  At 28 weeks of gestation it was noted on scans...
# 96  The deceased had considerable underlying natur...
# 97  On the 23 rd September 2023 after concerns wer...
# 98  Mr Colley was left unsupervised with cot sides...
# 99  Billie had been brought to the Royal Free Hosp...
#
#                                      MattersOfConcern  \
# 0   During the course of the investigation my inqu...
# 1   During the course of the inquest the evidence ...
# 2   During the course of the investigation my inqu...
# 3   During the course of the inquest the evidence ...
# 4   During the course of the inquest the evidence ...
# ..                                                ...
# 95  During the course of the inquest the evidence ...
# 96  During the course of the inquest the evidence ...
# 97  : A significant number of the serious causativ...
# 98  During the course of the inquest the evidence ...
# 99  During the course of the inquest, the evidence...
#
#                                               summary
# 0   Mr Dean Bradley died by hanging on 15 October ...
# 1   Mr Keith Ineson, a resident at Glenroyd Care H...
# 2   Paul Andrew Alexander, who had a long history ...
# 3   Abdirahman Abdirizaq Afrah, aged 17, died from...
# 4   Sophie Ann Louise Cotton, 24, died by suicide ...
# ..                                                ...
# 95  Alonzo Christopher Andrew Wood, born on 23 Sep...
# 96  Renate Mark, who had significant underlying he...
# 97  Darren Neil Turner, aged 37, died by suicide o...
# 98  Colin Colley, aged 87 with dementia, frailty, ...
# 99  Billie Wicks, aged 16, died from an infective ...
#
# [100 rows x 10 columns]

# %% [markdown]
# Next, we can estimate the number of tokens in our new column to make sure it's reasonable to feed to the model in one go. This method gets called downstream anyway, but we're calling it here to get an idea.

# %%
# Estimate the total number of tokens in the summary column
extractor.estimate_tokens()
# Out:
# 18327

# %% [markdown]
# ### Discover themes
#
# Next, we use the `self.discover_themes()` method to identify latent topics contained without our summarised corpus of reports. This method assumes that `self.summarise()` has already been run, and will throw an error if not.
#
# We can customise this method in several ways...
# 1. We can set `min_` and `max_themes` parameters. These are optional, default to None, and restrain the count of identified themes.
# 2. We can optionally provide seed topics to prod a model towards identifying specific themes. This parameter accepts a single string, a list of strings, or a Pydantic BaseModel.
# 3. Extra instructions can be provided if we want to control the model's behaviour in some other way. For example, we could instruct a model to only identify *systematic* concerns.
# 4. We can instuct the method to both warn us or throw an error if the number of tokens exceeds a certain number. These are set to reasonable default values for OpenAI models. To show it in action, we'll manually set `warn_exceed` to a small value.

# %%
extractor.discover_themes()

print(extractor.identified_themes)
# Out:
# ```json
# {
#   "mental_health": {
#     "type": "bool",
#     "description": "Issues related to mental health care, including assessment, treatment, communication, and crisis intervention failures."
#   },
#   "communication_failures": {
#     "type": "bool",
#     "description": "Breakdowns or inadequacies in communication between healthcare providers, agencies, patients, families, or within teams."
#   },
#   "care_planning": {
#     "type": "bool",
#     "description": "Deficiencies in care plans, risk assessments, monitoring, or follow-up arrangements leading to inadequate patient management."
#   },
#   "emergency_response": {
#     "type": "bool",
#     "description": "Delays, failures, or inadequacies in emergency services response, ambulance dispatch, or urgent care provision."
#   },
#   "documentation_issues": {
#     "type": "bool",
#     "description": "Incomplete, inaccurate, or missing records and documentation impacting patient care and clinical decision-making."
#   },
#   "interagency_coordination": {
#     "type": "bool",
#     "description": "Failures in collaboration, information sharing, or joint working between different agencies or services."
#   },
#   "staffing_shortages": {
#     "type": "bool",
#     "description": "Insufficient staffing levels or skill mix contributing to inadequate care or supervision."
#   },
#   "training_deficiencies": {
#     "type": "bool",
#     "description": "Lack of appropriate training, awareness, or competency among staff affecting patient safety."
#   },
#   "safeguarding_failures": {
#     "type": "bool",
#     "description": "Inadequate protection of vulnerable individuals, including failure to act on concerns or provide appropriate supervision."
#   },
#   "clinical_guidelines": {
#     "type": "bool",
#     "description": "Absence, poor implementation, or non-adherence to clinical protocols, guidelines, or best practice standards."
#   },
#   "information_systems": {
#     "type": "bool",
#     "description": "Problems with IT systems, data access, or interoperability hindering effective care and information flow."
#   },
#   "medication_management": {
#     "type": "bool",
#     "description": "Issues related to prescribing, monitoring, communication, or administration of medications."
#   },
#   "environmental_safety": {
#     "type": "bool",
#     "description": "Physical environment hazards, including inadequate safety measures, equipment risks, or unsafe infrastructure."
#   },
#   "delayed_diagnosis": {
#     "type": "bool",
#     "description": "Failures or delays in diagnosing conditions or escalating care leading to adverse outcomes."
#   },
#   "discharge_process": {
#     "type": "bool",
#     "description": "Problems with discharge planning, communication, or follow-up arrangements causing harm or inadequate care continuity."
#   },
#   "social_care": {
#     "type": "bool",
#     "description": "Failures or inadequacies in social care provision impacting patient safety, hospital flow, or community support."
#   },
#   "risk_assessment": {
#     "type": "bool",
#     "description": "Inadequate or absent assessment of patient risks, including falls, suicide, or clinical deterioration."
#   },
#   "patient_supervision": {
#     "type": "bool",
#     "description": "Insufficient monitoring or supervision of patients, especially those at high risk or with complex needs."
#   },
#   "systemic_failures": {
#     "type": "bool",
#     "description": "Wider organizational or systemic issues affecting multiple aspects of care and safety."
#   },
#   "access_barriers": {
#     "type": "bool",
#     "description": "Obstacles preventing timely access to care, services, or emergency interventions."
#   }
# }
# ```

# %%
extractor.discover_themes(max_themes=5, 
                          min_themes=5,
                          seed_topics="Factors implicitly or explicitly about staff shortages; potential issues with staff training",
                          extra_instructions=None,
                          warn_exceed=10000,
                          error_exceed=500000)

print(extractor.identified_themes)
# Out:
# WARNING:pfd_toolkit.extractor:Estimated token count 18327 exceeds warning threshold 10000
# ```json
# {
#   "staffing_shortages": {
#     "type": "bool",
#     "description": "Issues related to insufficient numbers of staff, including impacts on patient care, supervision, and service delivery."
#   },
#   "training_deficiencies": {
#     "type": "bool",
#     "description": "Concerns about inadequate or insufficient staff training, including lack of mandatory training, poor understanding of protocols, and skill gaps."
#   },
#   "communication_failures": {
#     "type": "bool",
#     "description": "Failures in communication within and between agencies, including poor information sharing, unclear handovers, and lack of coordination."
#   },
#   "systemic_process_gaps": {
#     "type": "bool",
#     "description": "Deficiencies in policies, procedures, protocols, or systemic frameworks that lead to missed or delayed interventions and poor outcomes."
#   },
#   "resource_and_capacity_constraints": {
#     "type": "bool",
#     "description": "Limitations in available resources such as beds, equipment, or social care capacity that cause delays, overcrowding, or inadequate care."
#   }
# }
# ```

# %% [markdown]
# We can see that staff shortages and training deficiencies have been added as the first two themes, with the model identifying 3 other themes (remember that we constrained its output to identify a maximum of 5 themes in total).

# %% [markdown]
# ### Assign themes to reports
#
# Finally, we can assign our generated list of themes to our original DataFrame containing the reports. We assigned the output to a new DataFrame. This adds new columns; one for each theme.
#
# An optional `force_assign` parameter prevents the model from outputting missing data for any given report field, while `allow_multiple` tells the model not to treat the list of themes as mutually exclusive (i.e. each report can have multiple themes). Both values default to `False`.

# %%
assigned_reports = extractor.extract_features(force_assign=True,
                                              allow_multiple=True,
                                              produce_spans=True)

assigned_reports.head(10)
# Out:
# Extracting features: 100%|██████████| 100/100 [00:29<00:00,  3.37it/s]
#                                                  URL         ID       Date  \
# 0  https://www.judiciary.uk/prevention-of-future-...  2025-0248 2025-05-28
# 1  https://www.judiciary.uk/prevention-of-future-...  2025-0243 2025-05-27
# 2  https://www.judiciary.uk/prevention-of-future-...  2025-0244 2025-05-27
# 3  https://www.judiciary.uk/prevention-of-future-...  2025-0245 2025-05-27
# 4  https://www.judiciary.uk/prevention-of-future-...  2025-0246 2025-05-27
# 5  https://www.judiciary.uk/prevention-of-future-...  2025-0241 2025-05-23
# 6  https://www.judiciary.uk/prevention-of-future-...  2025-0242 2025-05-23
# 7  https://www.judiciary.uk/prevention-of-future-...  2025-0247 2025-05-23
# 8  https://www.judiciary.uk/prevention-of-future-...  2025-0236 2025-05-21
# 9  https://www.judiciary.uk/prevention-of-future-...  2025-0240 2025-05-21
#
#       CoronerName                     Area  \
# 0    Clare Bailey  Teesside and Hartlepool
# 1  Andrew Cousins        Blackpool & Fylde
# 2  Peter Merchant      West Yorkshire West
# 3   Nadia Persaud              East London
# 4  Rebecca Sutton    Durham and Darlington
# 5    Mary Hassell       Inner North London
# 6    Mary Hassell       Inner North London
# 7   Nadia Persaud              East London
# 8  Kate Robertson         North West Wales
# 9    Andrew Morse      South Wales Central
#
#                                             Receiver  \
# 0  1 Department of Health and Social Care 2 Chief...
# 1                    BARCHESTER HEALTHCARE LIMITED 1
# 2        1 , Chief Constable West Yorkshire Police 1
# 3  , Chief Executive Officer, Barts Health NHS Fo...
# 4  1. Deputy Chief Constable , Durham Constabular...
# 5  1. Commissioner Metropolitan Police Service (M...
# 6  1. Director General Independent Office for Pol...
# 7  1. , CEO, North East London Foundation Trust (...
# 8  Betsi Cadwaladr University Health Board (BCUHB) 1
# 9  The Chief Executive Cardiff & Vale University ...
#
#                              InvestigationAndInquest  \
# 0  Mr Dean Bradley died on 15 th October 2021 at ...
# 1  On 30 April 2025 and 23 May 2025, at an inques...
# 2  On 15 February 2024 the death of Paul Andrew A...
# 3  On the 13 June 2024 I commenced an investigati...
# 4  On 7 January 2025 an investigation into the de...
# 5  On 12 February 2016, I commenced an investigat...
# 6  On 12 February 2016, I commenced an investigat...
# 7  On 27 November 2024 I commenced an investigati...
# 8  On 20 May 2024 I commenced an investigation in...
# 9  On 30 October 2023 I commenced an investigatio...
#
#                                 CircumstancesOfDeath  \
# 0  At approximately 0300 on 15 th October 2021 Mr...
# 1  I returned the following in box 4 of the Recor...
# 2  As identified above, Paul Alexander had a long...
# 3  Abdirahman Afrah began to suffer from chest pa...
# 4  The Deceased had a long history of mental heal...
# 5  Lewis Johnson died as a consequence of a road ...
# 6  Lewis Johnson died as a consequence of a road ...
# 7  Mr. Fraser was a 37-year-old gentleman who had...
# 8  The circumstances of the death are as follows ...
# 9  These were recorded as follows Robert Maxwell ...
#
#                                     MattersOfConcern  \
# 0  During the course of the investigation my inqu...
# 1  During the course of the inquest the evidence ...
# 2  During the course of the investigation my inqu...
# 3  During the course of the inquest the evidence ...
# 4  During the course of the inquest the evidence ...
# 5  2 During the course of the inquest, the eviden...
# 6  2 During the course of the inquest, the eviden...
# 7  During the course of the inquest the evidence ...
# 8  During the course of the inquest, the evidence...
# 9  During the course of the inquest the evidence ...
#
#                             spans_staffing_shortages staffing_shortages  \
# 0                                     N/A: Not found              False
# 1                                     N/A: Not found              False
# 2                                     N/A: Not found              False
# 3  "waiting times to be seen in Majors A&E at New...               True
# 4                                     N/A: Not found              False
# 5                                     N/A: Not found              False
# 6                                     N/A: Not found              False
# 7                                     N/A: Not found              False
# 8                                     N/A: Not found              False
# 9                                     N/A: Not found              False
#
#                          spans_training_deficiencies training_deficiencies  \
# 0                                     N/A: Not found                 False
# 1                                     N/A: Not found                 False
# 2                                     N/A: Not found                 False
# 3  "The inquest heard that the A&E doctor did not...                  True
# 4  "it was not best practice to have asked the ca...                  True
# 5  "failure by MPS to implement, disseminate and ...                  True
# 6                                     N/A: Not found                 False
# 7                                     N/A: Not found                 False
# 8  "The neonatal investigation was not thorough. ...                  True
# 9  "The guidance provided to clinicians and nursi...                  True
#
#                         spans_communication_failures communication_failures  \
# 0  "The police failed to contact the mental healt...                   True
# 1                                     N/A: Not found                  False
# 2  "call was redirected to the ambulance service ...                   True
# 3  "When the doctor called Abdirahman the followi...                   True
# 4  "During the 16:44 call, by following the “Righ...                   True
# 5  "not a consistent expectation among police off...                   True
# 6                                     N/A: Not found                  False
# 7  "The team did not make it clear to the family ...                   True
# 8  "There was no sufficiently full contextual sha...                   True
# 9  "The guidance provided to clinicians and nursi...                   True
#
#                          spans_systemic_process_gaps systemic_process_gaps  \
# 0  "There appears to be a gap in the services ava...                  True
# 1  "observation scores taken for Mr Ineson follow...                  True
# 2  "Under the Right Care Right Person framework, ...                  True
# 3  "There was no timely triage of Majors patients...                  True
# 4  "During the 16:44 call, by following the “Righ...                  True
# 5  "failure by MPS to implement, disseminate and ...                  True
# 6  "the terms of reference set out for the forens...                  True
# 7  "There was no clear care plan in place whilst ...                  True
# 8  "There were several opportunities not taken by...                  True
# 9  "The guidance provided to clinicians and nursi...                  True
#
#              spans_resource_and_capacity_constraints  \
# 0  "Current resources for safeguarding those with...
# 1                                     N/A: Not found
# 2                                     N/A: Not found
# 3  "there were no beds available and that he woul...
# 4                                     N/A: Not found
# 5                                     N/A: Not found
# 6                                     N/A: Not found
# 7                                     N/A: Not found
# 8                                     N/A: Not found
# 9                                     N/A: Not found
#
#   resource_and_capacity_constraints
# 0                              True
# 1                             False
# 2                             False
# 3                              True
# 4                             False
# 5                             False
# 6                             False
# 7                             False
# 8                             False
# 9                             False

# %%
print(extractor.feature_model)
# Out:
# <class 'pfd_toolkit.extractor.DiscoveredThemesWithSpans'>
