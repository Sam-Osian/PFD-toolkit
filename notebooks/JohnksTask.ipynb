# %% [markdown]
# ## John's Task: Categorisation System for PFD Reports
#
# ### Purpose
#
# The goal of this task is to create a `Categoriser` module for PFD Toolkit. This will be a robust way that users can categorise Prevention of Future Death (PFD) reports using our LLM class. The system should support both broad themes and granular sub-categories that help organise the content for research, policy, and analysis.
#
# This is probably the most useful and exciting feature of the Toolkit because it will mean researchers no longer have to manually sift through reports to check whether they're relevant to their research goals, which can take months or even years.
#
#
# ### Format
#
# I would like the user to be able to provide a custom schema in the following format:
#
# > ```Theme, Sub-theme, Description/keywords```
#
# This schema will guide the LLM in assigning categories.
#
# ### Mock research question
#
# To give this task some direction, here's a mock research question you can work from. This is optional - feel free to choose a different framing if it’s more useful for testing.
#
# Your research question is:
# > **"*Where* are suicide deaths preventable?"**
#
# The aim of the research question is to understand the specific venues or contexts behind a preventable death by suicide. This aim is important, because it allows policymakers to identify key priorities for where we could change public policy or NHS practice, ultimately saving lives.
#
#
# ### Mock schema
# Below is a mock-up of the schema that you may wish to run. You don’t need to follow this format exactly (e.g. you’ll likely want to use Pydantic), but here’s a structured example of what I’m hoping the schema will support:
#
# ```
# {
#   "suicide": {
#     "drug_related": [
#       "overdose",
#       "toxicity",
#       "substance_misuse",
#       "medication_error",
#       "intoxication",
#       "polypharmacy"
#     ],
#     "institutional_settings": [
#       "prison",
#       "police_custody",
#       "mental_health_inpatient",
#       "secure_hospital",
#       "approved_premises",
#       "detention_centre"
#     ],
#     "community_care_failures": [
#       "missed_referral",
#       "inadequate_risk_assessment",
#       "lack_of_follow_up",
#       "gp_did_not_refer",
#       "mental_health_team_failure",
#       "discharged_without_support"
#     ],
#     "communication_errors": [
#       "records_not_shared",
#       "poor_handover",
#       "discharge_summary_not_sent",
#       "information_not_passed_on",
#       "care_coordination_failure"
#     ],
#     "access_to_means": [
#       "ligature_point",
#       "firearm",
#       "railway_access",
#       "jumped_from_height",
#       "chemical_ingestion",
#       "access_to_high_risk_medication"
#     ],
#     "recent_contact_with_services": [
#       "seen_by_gp",
#       "discharged_from_hospital",
#       "recent_ae_attendance",
#       "under_mental_health_services",
#       "in_care_of_crisis_team"
#     ],
#     "domestic_or_social_factors": [
#       "domestic_abuse",
#       "relationship_breakdown",
#       "social_isolation",
#       "recent_bereavement",
#       "housing_insecurity"
#     ],
#     "youth_or_transitional_risk": [
#       "under_25",
#       "child_and_adolescent_services",
#       "transition_to_adult_services",
#       "excluded_from_school",
#       "care_leaver"
#     ]
#   }
# }
# ```
#
# Note that above, we only have 1 top-level theme ("suicide") with everything contained within it being sub-themes and descriptions.
#
# ### Further instructions
#
# The default LLM model is `gpt-4.1-mini`, which works fantastically well. However, `gpt-4.1-nano` is much cheaper (but often fails to follow instructions). To save on API costs, please use the nano model for development, and the mini model for making sure it actually works.
#
# Please implement the following:
#
# - The categorisation module should return the original reports DataFrame, with **additional columns** for each theme and sub-theme. Values in these columns should be `"Yes"` or `"No"` depending on whether the report meets the criteria.
#
# - Add a **boolean parameter** that controls whether a report can be assigned to **multiple themes / sub-themes** or must be assigned to only the most appropriate one.
#
# - Add the **same parameter for sub-themes**, allowing control over single vs. multi-label classification at both levels.
#
# - Add Boolean parameters that determine whether certain sections should be fed to the model. For example, `include_circumstances=False` would mean that this section is never fed to the LLM, saving input tokens. The URL, ID, Date, Coroner name, and Receiver should be `False` by default, with the other sections being `True` by default.
#
# - Please place all **LLM-specific logic** in the `llm.py` module. Everything else should go in a new `categoriser.py` module. In `llm.py`, you’ll notice how the base prompts and config are structured for the `Cleaner` class — I’d love if you could mirror that for this.
#
# - Please ensure that changes made to `llm.py` are non-destructive (i.e. make sure you only 'add' features, not take any functionality away). If you're unsure, please do test on the two `DEMO` notebooks.
#
# ---
#
# ### Optional Features, in order of preference (if you have time or feel inclined)
#
# - The `LLM` class has a `max_workers` parameter for parallel processing. Your work should ideally use this to speed things up.
#
# - Add a Boolean parameter that controls whether the **third tier (description/keywords)** should be treated as **sub-sub-themes** (i.e. distinct columns), or just descriptive phrases to support assignment to the sub-theme level.
#
# - If implemented, please apply the same `"Yes"/"No"` structure for sub-sub-themes. Please also extend your multi- or single-theme assignment parameter to the sub-sub-theme.
#
# - Add a Boolean parameter to **automatically include an "Other / None of the above"** category at the theme, sub-theme, or sub-sub-theme level as appropriate.
#
# ---
#
# ### What you **don't** need to do
#
# - You don't need to do any formal evaluation - that's for me to do! It would be good if you could eyeball the outputs though to make sure everything looks right. I can then go from there.

# %% [markdown]
# ### Getting the data
#
# There are two files you'll need for the mock research question.
#
# 1. `../data/suicide_reports.csv` -- 293 scraped, suicide-specific reports spanning from 1st May 2023 to 1st May 2025.
# 2. `../data/suicide_reports_sample.csv` -- a sample of 50 reports you can use for development to save on token costs.
#
# You do not need to run the below blocks; it's just to show where the datasets came from.

# %%
import pandas as pd

sample_reports= pd.read_csv('../data/suicide_reports_sample.csv')
sample_reports.columns
# Out:
# Index(['URL', 'ID', 'Date', 'CoronerName', 'Area', 'Receiver',
#        'InvestigationAndInquest', 'CircumstancesOfDeath', 'MattersOfConcern'],
#       dtype='object')

# %% [markdown]
# ### How I'd like the API to look
#
# This isn't a requirement, just a suggestion!
#
# The below code will NOT run because the module hasn't been created yet. It's just a mock-up of what I'm imagining. Notice how it closely resembles the PFDScraper and Cleaner classes for a nice, harmonised user-interface.

# %%
json_schema = {
  "suicide": {
    "drug_related": [
      "overdose",
      "toxicity",
      "substance_misuse",
      "medication_error",
      "intoxication",
      "polypharmacy"
    ],
    "institutional_settings": [
      "prison",
      "police_custody",
      "mental_health_inpatient",
      "secure_hospital",
      "approved_premises",
      "detention_centre"
    ],
    "community_care_failures": [
      "missed_referral",
      "inadequate_risk_assessment",
      "lack_of_follow_up",
      "gp_did_not_refer",
      "mental_health_team_failure",
      "discharged_without_support"
    ],
    "communication_errors": [
      "records_not_shared",
      "poor_handover",
      "discharge_summary_not_sent",
      "information_not_passed_on",
      "care_coordination_failure"
    ],
    "access_to_means": [
      "ligature_point",
      "firearm",
      "railway_access",
      "jumped_from_height",
      "chemical_ingestion",
      "access_to_high_risk_medication"
    ],
    "recent_contact_with_services": [
      "seen_by_gp",
      "discharged_from_hospital",
      "recent_ae_attendance",
      "under_mental_health_services",
      "in_care_of_crisis_team"
    ],
    "domestic_or_social_factors": [
      "domestic_abuse",
      "relationship_breakdown",
      "social_isolation",
      "recent_bereavement",
      "housing_insecurity"
    ],
    "youth_or_transitional_risk": [
      "under_25",
      "child_and_adolescent_services",
      "transition_to_adult_services",
      "excluded_from_school",
      "care_leaver"
    ]
  }
}

# %%
from pydantic import BaseModel
from typing import Literal
def get_categorisation_model(categories: list[str]) -> BaseModel:
    class Categorisation(BaseModel):
        category: Literal[tuple(categories)] # type: ignore
    return Categorisation

# %%
from pfd_toolkit import Categoriser, LLM
from dotenv import load_dotenv
import os

# Get API key
load_dotenv("api.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

# Set up LLM client
llm_client = LLM(api_key=openai_api_key, 
                 max_workers=30) # Max workers to parallelise Categoriser tasks

categoriser = Categoriser(
    # Most important:
    reports = sample_reports, # Dataframe containing scraped reports
    llm = llm_client,
    json_schema = json_schema,
    
    # Other desired functionality as optional params
    third_tier_as_theme = True, # ...whether to treat the third tier as a sub-sub-theme (True) or just as a description of the sub-theme (False)
    multi_assignment = True, # ...whether reports can be assigned to multiple themes and sub-themes (True) or not (False)
    include_date = False, # All existing columns need a toggle for whether this should be fed to the model. `include_date` is just one example
)

# categoriser.reports # Returns DataFrame with additional Yes/No columns for each theme / sub-theme / sub-sub-theme (if using)
# categoriser.tabulation # Returns a DataFrame with the counts of each theme / sub-theme / sub-sub-theme (if using). I can develop this myself :)

# %%
categoriser.categorise_reports()
# Out:
#                                                   URL         ID  \
# 0   https://www.judiciary.uk/prevention-of-future-...  2024-0328
# 1   https://www.judiciary.uk/prevention-of-future-...  2023-0185
# 2   https://www.judiciary.uk/prevention-of-future-...  2024-0159
# 3   https://www.judiciary.uk/prevention-of-future-...  2024-0646
# 4   https://www.judiciary.uk/prevention-of-future-...  2024-0405
# 5   https://www.judiciary.uk/prevention-of-future-...  2025-0079
# 6   https://www.judiciary.uk/prevention-of-future-...  2024-0514
# 7   https://www.judiciary.uk/prevention-of-future-...  2023-0510
# 8   https://www.judiciary.uk/prevention-of-future-...  2024-0541
# 9   https://www.judiciary.uk/prevention-of-future-...  2023-0521
# 10  https://www.judiciary.uk/prevention-of-future-...  2024-0535
# 11  https://www.judiciary.uk/prevention-of-future-...  2025-0127
# 12  https://www.judiciary.uk/prevention-of-future-...  2024-0143
# 13  https://www.judiciary.uk/prevention-of-future-...  2024-0198
# 14  https://www.judiciary.uk/prevention-of-future-...  2025-0124
# 15  https://www.judiciary.uk/prevention-of-future-...  2025-0104
# 16  https://www.judiciary.uk/prevention-of-future-...  2024-0093
# 17  https://www.judiciary.uk/prevention-of-future-...  2024-0665
# 18  https://www.judiciary.uk/prevention-of-future-...  2023-0313
# 19  https://www.judiciary.uk/prevention-of-future-...  2023-0528
# 20  https://www.judiciary.uk/prevention-of-future-...  2024-0373
# 21  https://www.judiciary.uk/prevention-of-future-...  2024-0362
# 22  https://www.judiciary.uk/prevention-of-future-...  2024-0442
# 23  https://www.judiciary.uk/prevention-of-future-...  2023-0146
# 24  https://www.judiciary.uk/prevention-of-future-...  2023-0390
# 25  https://www.judiciary.uk/prevention-of-future-...  2024-0528
# 26  https://www.judiciary.uk/prevention-of-future-...  2024-0270
# 27  https://www.judiciary.uk/prevention-of-future-...  2023-0534
# 28  https://www.judiciary.uk/prevention-of-future-...  2024-0710
# 29  https://www.judiciary.uk/prevention-of-future-...  2023-0388
# 30  https://www.judiciary.uk/prevention-of-future-...  2024-0219
# 31  https://www.judiciary.uk/prevention-of-future-...  2024-0448
# 32  https://www.judiciary.uk/prevention-of-future-...  2024-0114
# 33  https://www.judiciary.uk/prevention-of-future-...  2024-0089
# 34  https://www.judiciary.uk/prevention-of-future-...  2024-0340
# 35  https://www.judiciary.uk/prevention-of-future-...  2023-0223
# 36  https://www.judiciary.uk/prevention-of-future-...  2023-0362
# 37  https://www.judiciary.uk/prevention-of-future-...  2019-0397
# 38  https://www.judiciary.uk/prevention-of-future-...  2023-0368
# 39  https://www.judiciary.uk/prevention-of-future-...  2024-0115
# 40  https://www.judiciary.uk/prevention-of-future-...  2024-0269
# 41  https://www.judiciary.uk/prevention-of-future-...  2023-0173
# 42  https://www.judiciary.uk/prevention-of-future-...  2023-0133
# 43  https://www.judiciary.uk/prevention-of-future-...  2023-0220
# 44  https://www.judiciary.uk/prevention-of-future-...  2024-0102
# 45  https://www.judiciary.uk/prevention-of-future-...  2024-0377
# 46  https://www.judiciary.uk/prevention-of-future-...  2024-0524
# 47  https://www.judiciary.uk/prevention-of-future-...  2024-0124
# 48  https://www.judiciary.uk/prevention-of-future-...  2024-0239
# 49  https://www.judiciary.uk/prevention-of-future-...  2024-0453
#
#                                        Area  \
# 0                      South Yorkshire West
# 1                          North West Wales
# 2                                  Cheshire
# 3                                    Dorset
# 4                               East London
# 5       Nottingham City and Nottinghamshire
# 6                                    Surrey
# 7                                     Essex
# 8                            Worcestershire
# 9                        Inner North London
# 10                                    Essex
# 11              SWANSEA & NEATH PORT TALBOT
# 12                         Manchester South
# 13             Gateshead and South Tyneside
# 14                                 Coventry
# 15                             South London
# 16           West Sussex, Brighton and Hove
# 17                                Berkshire
# 18                              East London
# 19                                 Cheshire
# 20                            Hertfordshire
# 21                            East Sussex 2
# 22    Hampshire, Portsmouth and Southampton
# 23                             North London
# 24                         Manchester South
# 25                            Staffordshire
# 26         Staffordshire and Stoke on Trent
# 27                        Inner West London
# 28           Nottingham and Nottinghamshire
# 29                                   Dorset
# 30  Leicester City and South Leicestershire
# 31                              Oxfordshire
# 32                   Bedfordshire and Luton
# 33                         Manchester South
# 34                            Herefordshire
# 35                            Herefordshire
# 36                              West London
# 37         Cornwall and the Isles of Scilly
# 38                             Lincolnshire
# 39      Nottingham City and Nottinghamshire
# 40                       Inner North London
# 41                              East London
# 42                             South London
# 43                         Manchester South
# 44                 West Yorkshire (Eastern)
# 45                        Inner West London
# 46                         Manchester South
# 47                       Inner North London
# 48          Cambridgeshire and Peterborough
# 49                       Inner North London
#
#                               InvestigationAndInquest  \
# 0   On 19 October 2023 I commenced an investigatio...
# 1   On 21 June 2022 an investigation was commenced...
# 2   On 14 November 2023 I commenced an investigati...
# 3   On the 4 th April 2023, an investigation was c...
# 4   On 12 April 2023 I commenced an investigation ...
# 5   On 5 April 2023, I commenced an investigation ...
# 6   On 30 th May 2023 an inquest was opened into t...
# 7   On 26 October 2022 I commenced an investigatio...
# 8   On 16 January 2023 I commenced an investigatio...
# 9   On 17 May 2023, one of my assistant coroners, ...
# 10  On 4 January 2022 an investigation was commenc...
# 11  On 18th February and 5th March 2025 I heard an...
# 12  On 22nd February 2023 I commenced an investiga...
# 13  On 22nd November 2021 I commenced an investiga...
# 14  On 13 th August 2021 I commenced an investigat...
# 15  On 15 th January 2020 an inquest was opened in...
# 16  On 26 th September, 2018 I commenced an invest...
# 17  On 15 September 2023 I commenced an investigat...
# 18  On 3 August 2022 I commenced an investigation ...
# 19  On 23 September 2021 I commenced an investigat...
# 20  On 7 August 2017 an investigation was commence...
# 21  On 04 July 2023 I commenced an investigation i...
# 22  On 7th March 2020 an investigation commenced i...
# 23  On the 31st August 2022 I opened an investigat...
# 24  On 9th May 2023 I commenced an investigation i...
# 25  On the 10 January 2024 2017, I commenced an in...
# 26  On 12 April 2023 I commenced an investigation ...
# 27  On the 5th December 2023 evidence was heard to...
# 28  On 29 th April 2024 an inquest was opened into...
# 29  On the 18th May 2022, an investigation was com...
# 30  On 12 August 2021 I commenced an investigation...
# 31  On the 5 April 2023 an Inquest was opened into...
# 32  On 20 January 2023 I commenced an investigatio...
# 33  On the 25th October 2022, I commenced an inves...
# 34  On 13 January 2023 I commenced an investigatio...
# 35  On 9 May 2022 I commenced an investigation int...
# 36  An investigation was commenced into the death ...
# 37  On 3 May 2018, an inquest was opened into the ...
# 38  On 08 February 2023 I commenced an investigati...
# 39  On 11 May 2022 I commenced an investigation in...
# 40  On 27/11/2020 an investigation commenced into ...
# 41  On 11 March 2022 I commenced an investigation ...
# 42  Samuel Thomas Howes On 17th September 2020, th...
# 43  On 6th October 2020 I commenced an investigati...
# 44  On 30th June 2023 I commenced an investigation...
# 45  On 12 July 2023 I commenced an investigation i...
# 46  On 29 th August 2023 an investigation was comm...
# 47  On 6 October 2023, an investigation was commen...
# 48  On 02 September 2021 I commenced an investigat...
# 49  On 5 February 2021 the Senior Coroner, Mary Ha...
#
#                                  CircumstancesOfDeath  \
# 0   Jacob was in long term foster care. Following ...
# 1   The circumstances of the death are as follows ...
# 2   Mary Jones was found dead at her home address ...
# 3   Emma had a complex mental health history with ...
# 4   Danny Anderson suffered from chronic mental he...
# 5   Serco had operated HMP Lowdham Grange, Notting...
# 6   See the details set out in the narrative concl...
# 7   Katharine Fox was being treated at home follow...
# 8   In answer to the questions “when, where and ho...
# 9   Michael Hindes killed himself [REDACTED]. One ...
# 10  James Agius was found deceased at home on 17 D...
# 11  On 18 May 2022 Jean Pike was stating that she ...
# 12  Tobias Mannering-Jones was very vulnerable. He...
# 13  Stevyn Carr contacted Northumbria Police on th...
# 14  Mr GEBRSSLASIE on the 2nd August 2021 was arre...
# 15  Mr Paul Dunne had a history of depression, anx...
# 16                              See Record of Inquest
# 17  On the 11th September 2023 Charlie Anthony Owe...
# 18  Allison Aules was referred to the mental healt...
# 19  Olivia Russell had a history of anxiety which ...
# 20  Megan Davison was found deceased at her home a...
# 21  On the morning of 28 June 2023 Thomas Joseph G...
# 22  In January 2020 Craig Steadman was released fr...
# 23  On the 27th August 2022 Callum Wong was found ...
# 24  Holly May Mullan had longstanding severe abdom...
# 25  i). Miss Knowles was 30 years of age, with in ...
# 26  Mr Luke Pearce was found hanging in his cell o...
# 27  Extensive evidence was heard by the court in t...
# 28  Paul Taylor had been under police investigatio...
# 29  On the 15th May 2022 Marnie Emma Hill was foun...
# 30  Ash Bannister was a 16 year old who was assign...
# 31  The immediate circumstances are that: On 24 Ma...
# 32  The Deceased suffered with physical disabiliti...
# 33  Sam had a long history of anxiety and depressi...
# 34  Nicola Jane Lacey lived alone in a large prope...
# 35  On 01.2.22, Mr Griffiths went from home by amb...
# 36  Jack had a history of difficulties with his me...
# 37  On 4 April 2018, was interviewed by Devon and ...
# 38  91 years old who lived alone, no carers but ha...
# 39  Daniel (referred to as Dan at the request of h...
# 40  Mr Monoja had a history of chronic paranoid an...
# 41  Conrad Colson suffered from severe body dysmor...
# 42  A jury found: Suicide Samuel's mental health a...
# 43  Michelle Louise Jennings had a history of cont...
# 44  Matthew Gregory Price was aged 48. He was conv...
# 45  Mrs Obholzer took her own life by jumping in f...
# 46  On 25th August 2023 Michael Sean Heath died in...
# 47  On 24 September 2023, Sandra Senior travelled ...
# 48  Kellie Sutton had experienced a series of rela...
# 49  (1) Immediately prior to her detention the Dec...
#
#                                      MattersOfConcern  suicide  \
# 0   During the course of the inquest the evidence ...      NaN
# 1   During the course of the inquest, the evidence...      NaN
# 2   During the course of the investigation my inqu...      NaN
# 3   During the course of the inquest the evidence ...      NaN
# 4   During the course of the inquest the evidence ...      NaN
# 5   During the course of the inquest the evidence ...      NaN
# 6   During the course of the inquest the evidence ...      NaN
# 7   During the course of the inquest the evidence ...      NaN
# 8   During the course of the inquest the evidence ...      NaN
# 9   During the course of the inquest, the evidence...      NaN
# 10  During the course of the inquest the evidence ...      NaN
# 11  During the inquest the evidence revealed matte...      NaN
# 12  During the course of the inquest the evidence ...      NaN
# 13  During the course of the inquest the evidence ...      NaN
# 14  During the inquest, the evidence and informati...      NaN
# 15  Many of the failings have been addressed local...      NaN
# 16  During the course of the inquest the evidence ...      NaN
# 17  During the course of the investigation my inqu...      NaN
# 18  During the course of the inquest the evidence ...      NaN
# 19  During the course of the investigation my inqu...      NaN
# 20  During the course of the inquest the evidence ...      NaN
# 21  During the course of the investigation my inqu...      NaN
# 22  During the course of the investigation my inqu...      NaN
# 23  The MATTERS OF CONCERN are as follows. – 1. Co...      NaN
# 24  During the course of the inquest the evidence ...      NaN
# 25  During the course of the inquest the evidence ...      NaN
# 26  During the course of the investigation my inqu...      NaN
# 27  (3) [REDACTED] is a forum that permits materia...      NaN
# 28  ; When a suspect is arrested for offences requ...      NaN
# 29  During the course of the inquest the evidence ...      NaN
# 30  During the course of the investigation my inqu...      NaN
# 31  During the course of the inquest the evidence ...      NaN
# 32  During the course of the investigation my inqu...      NaN
# 33  During the course of the inquest the evidence ...      NaN
# 34  During the course of the inquest the evidence ...      NaN
# 35  During the course of the inquest the evidence ...      NaN
# 36  During the inquest, the evidence revealed matt...      NaN
# 37  During the course of the inquest the evidence ...      NaN
# 38  Regulation 28 – After Inquest Document Templat...      NaN
# 39  During the course of the investigation my inqu...      NaN
# 40  During the course of the inquest the evidence ...      NaN
# 41  During the course of the inquest the evidence ...      NaN
# 42  During the course of the investigation, the ev...      NaN
# 43  During the course of the inquest the evidence ...      NaN
# 44  During the course of the Inquest the evidence ...      NaN
# 45  During the course of the inquest the evidence ...      NaN
# 46  The evidence heard during the inquest into Mic...      NaN
# 47  During the course of the investigation and inq...      NaN
# 48  During the course of the investigation my inqu...      NaN
# 49  During the course of the inquest, the evidence...      NaN
#
#     suicide-drug_related  suicide-drug_related-overdose  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
# 5                    NaN                            NaN
# 6                    NaN                            NaN
# 7                    NaN                            NaN
# 8                    NaN                            NaN
# 9                    NaN                            NaN
# 10                   NaN                            NaN
# 11                   NaN                            NaN
# 12                   NaN                            NaN
# 13                   NaN                            NaN
# 14                   NaN                            NaN
# 15                   NaN                            NaN
# 16                   NaN                            NaN
# 17                   NaN                            NaN
# 18                   NaN                            NaN
# 19                   NaN                            NaN
# 20                   NaN                            NaN
# 21                   NaN                            NaN
# 22                   NaN                            NaN
# 23                   NaN                            NaN
# 24                   NaN                            NaN
# 25                   NaN                            NaN
# 26                   NaN                            NaN
# 27                   NaN                            NaN
# 28                   NaN                            NaN
# 29                   NaN                            NaN
# 30                   NaN                            NaN
# 31                   NaN                            NaN
# 32                   NaN                            NaN
# 33                   NaN                            NaN
# 34                   NaN                            NaN
# 35                   NaN                            NaN
# 36                   NaN                            NaN
# 37                   NaN                            NaN
# 38                   NaN                            NaN
# 39                   NaN                            NaN
# 40                   NaN                            NaN
# 41                   NaN                            NaN
# 42                   NaN                            NaN
# 43                   NaN                            NaN
# 44                   NaN                            NaN
# 45                   NaN                            NaN
# 46                   NaN                            NaN
# 47                   NaN                            NaN
# 48                   NaN                            NaN
# 49                   NaN                            NaN
#
#     suicide-drug_related-toxicity  ...  \
# 0                             NaN  ...
# 1                             NaN  ...
# 2                             NaN  ...
# 3                             NaN  ...
# 4                             NaN  ...
# 5                             NaN  ...
# 6                             NaN  ...
# 7                             NaN  ...
# 8                             NaN  ...
# 9                             NaN  ...
# 10                            NaN  ...
# 11                            NaN  ...
# 12                            NaN  ...
# 13                            NaN  ...
# 14                            NaN  ...
# 15                            NaN  ...
# 16                            NaN  ...
# 17                            NaN  ...
# 18                            NaN  ...
# 19                            NaN  ...
# 20                            NaN  ...
# 21                            NaN  ...
# 22                            NaN  ...
# 23                            NaN  ...
# 24                            NaN  ...
# 25                            NaN  ...
# 26                            NaN  ...
# 27                            NaN  ...
# 28                            NaN  ...
# 29                            NaN  ...
# 30                            NaN  ...
# 31                            NaN  ...
# 32                            NaN  ...
# 33                            NaN  ...
# 34                            NaN  ...
# 35                            NaN  ...
# 36                            NaN  ...
# 37                            NaN  ...
# 38                            NaN  ...
# 39                            NaN  ...
# 40                            NaN  ...
# 41                            NaN  ...
# 42                            NaN  ...
# 43                            NaN  ...
# 44                            NaN  ...
# 45                            NaN  ...
# 46                            NaN  ...
# 47                            NaN  ...
# 48                            NaN  ...
# 49                            NaN  ...
#
#     suicide-domestic_or_social_factors-relationship_breakdown  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-domestic_or_social_factors-social_isolation  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-domestic_or_social_factors-recent_bereavement  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-domestic_or_social_factors-housing_insecurity  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-youth_or_transitional_risk  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36                                 NaN
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41                                 NaN
# 42                                 NaN
# 43                                 NaN
# 44                                 NaN
# 45                                 NaN
# 46                                 NaN
# 47                                 NaN
# 48                                 NaN
# 49                                 NaN
#
#     suicide-youth_or_transitional_risk-under_25  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 40                                          NaN
# 41                                          NaN
# 42                                          NaN
# 43                                          NaN
# 44                                          NaN
# 45                                          NaN
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49                                          NaN
#
#     suicide-youth_or_transitional_risk-child_and_adolescent_services  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-youth_or_transitional_risk-transition_to_adult_services  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-youth_or_transitional_risk-excluded_from_school  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     suicide-youth_or_transitional_risk-care_leaver
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# 30                                             NaN
# 31                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 35                                             NaN
# 36                                             NaN
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
# 42                                             NaN
# 43                                             NaN
# 44                                             NaN
# 45                                             NaN
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
#
# [50 rows x 59 columns]

# %%
def traverse_category_tree(json_schema: dict | list, final_node: bool = False):
    if not final_node:
        keys = list(json_schema.keys()) # all parent nodes are dicts
    else:
        keys = json_schema # the last node is just a list

    model = get_categorisation_model(keys)
    result = generate('prompt', model)
    if not final_node:
        if isinstance(json_schema[result], dict):
            # traverse
            traverse_category_tree(json_schema)
        else:
            assert isinstance(json_schema[result], list) # sanity check
            traverse_category_tree(json_schema[result], final_node=True)
    else:
        # we've traversed to the maximum depth of this tree
        pass
