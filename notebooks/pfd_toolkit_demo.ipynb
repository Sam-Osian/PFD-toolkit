# %% [markdown]
# ## Demoing PFD Toolkit
#
# The below is a demo build of PFD Toolkit version 0.1.27.
#
# Note that all below code will not actually run on machines other than my own, as the toolkit is not on `pip` yet.
#
# Each code block is accompanied with a `%%time` command. This prints the CPU and wall times of the code so you can get a better sense of its speed.

# %% [markdown]
# ### Load reports
#
# The dataset containing PFD reports is bundled with the package. The user can load reports somewhat similar to how an R user can load Iris. However, unlike Iris, PFD reports are automatically refreshed weekly with new reports courtesy of GitHub Workflows.
#
# To save money on OpenAI credits, this feature has only been implemented with HTML scraping for now. Eventually, this will be replaced by the more performative LLM scraping.

# %%
# %%time

from pfd_toolkit import load_reports

# Load all reports from the month of April 2025
reports = load_reports(start_date = "2025-04-01",
                       end_date="2025-04-30")

reports.head(n=10)
# Out:
# CPU times: user 103 ms, sys: 7.95 ms, total: 111 ms
# Wall time: 110 ms
#                                                   URL         ID       Date  \
# 30  https://www.judiciary.uk/prevention-of-future-...  2025-0208 2025-04-30
# 31  https://www.judiciary.uk/prevention-of-future-...  2025-0207 2025-04-30
# 32  https://www.judiciary.uk/prevention-of-future-...  2025-0120 2025-04-25
# 33  https://www.judiciary.uk/prevention-of-future-...  2025-0206 2025-04-25
# 34  https://www.judiciary.uk/prevention-of-future-...  2025-0120 2025-04-24
# 35  https://www.judiciary.uk/prevention-of-future-...  2025-0199 2025-04-24
# 36  https://www.judiciary.uk/prevention-of-future-...  2025-0194 2025-04-23
# 37  https://www.judiciary.uk/prevention-of-future-...  2025-0120 2025-04-23
# 38  https://www.judiciary.uk/prevention-of-future-...  2025-0193 2025-04-23
# 39  https://www.judiciary.uk/prevention-of-future-...  2025-0198 2025-04-23
#
#         CoronerName                            Area  \
# 30   Joanne Andrews  West Sussex, Brighton and Hove
# 31     Alison Mutch                Manchester South
# 32     Mary Hassell              Inner North London
# 33   Jonathan Heath        North Yorkshire and York
# 34   Samantha Marsh                        Somerset
# 35  Samantha Goward                         Norfolk
# 36     Heidi Connor                       Berkshire
# 37     Kerrie Burge             South Wales Central
# 38     Heidi Connor                       Berkshire
# 39  Louisa Corcoran                      Ceredigion
#
#                                              Receiver  \
# 30                       West Sussex County Council 1
# 31  1) Flixton Road Medical Centre 2) Greater Manc...
# 32  1. The President Royal College Obstetricians a...
# 33                                   Townhead Surgery
# 34  Part 1 1. Somerset Foundation Trust of Trust M...
# 35                     The Department for Transport 1
# 36  1 , President of the Association of Coloprocto...
# 37  The Chief Executive, Rhondda Cynon Taf County ...
# 38  1 , Chief Executive of Royal Berkshire NHS Fou...
# 39  to:- REGULATION 28 REPORT TO PREVENT FUTURE DE...
#
#                               InvestigationAndInquest  \
# 30  On 02 November 2024 I commenced an investigati...
# 31  On 1st October 2024 I commenced an investigati...
# 32  On 23 August 2024, one of my assistant coroner...
# 33  On 04 June 2024 I commenced an investigation i...
# 34  On 6 th December 2022 I commenced an investiga...
# 35  On 22 August 2024 I commenced an investigation...
# 36  The family requested me to refer to the deceas...
# 37  On 26 June 2023, I commenced an investigation ...
# 38  The family requested me to refer to the deceas...
# 39  On 8 August 2022, an investigation into the de...
#
#                                  CircumstancesOfDeath  \
# 30  Mrs Turner drove her car into the canal at the...
# 31  Louise Danielle Rosendale was prescribed long ...
# 32  Jannat was a big baby and her mother had a his...
# 33  On 15 March 2024, Richard James Moss attended ...
# 34  Anne first presented to her GP in 2008. During...
# 35  In summary, on the 17th of August 2024 Mr Mill...
# 36  This can be summarised by my findings on the R...
# 37  These were recorded as follows: Martin Robert ...
# 38  Lorraine Parker's death was the third in three...
# 39  Mr Brazil had suffered from an accident some t...
#
#                                      MattersOfConcern
# 30  During the course of the investigation my inqu...
# 31  During the course of the inquest the evidence ...
# 32  During the course of the inquest, the evidence...
# 33  During the course of the inquest the evidence ...
# 34  4 During the course of the inquest the evidenc...
# 35  During the course of the investigation my inqu...
# 36  During the course of the investigation my inqu...
# 37  During the course of the inquest the evidence ...
# 38  During the course of the investigation my inqu...
# 39  During the course of the inquest the evidence ...

# %% [markdown]
# ### Running the scraper
#
# There could be circumstances where the user wishes to run their own Scraper rather than simply loading the reports above. For example, we are currently considering whether the reports available through `load_reports` should be cleaned & recategorised - in which case, some users may wish to scrape the raw reports.
#
# Our scraper has 3 cascading features:
#
# 1. Attempts to parse structured data from the primary **HTML** page of a report.
# 2. If HTML parsing is insufficient or disabled, it falls back to extracting text from the linked **PDF** document and parsing sections based on keywords.
# 3. If both HTML and PDF methods fail to retrieve necessary information, it can use a **Vision Large Language Model (LLM)** for extraction, provided an LLM client is configured.
#
# Each of these 3 options can be disabled. If LLM scraping is used, the user must import the `LLM` module from the package.

# %%
# %%time

from pfd_toolkit import PFDScraper, LLM
from dotenv import load_dotenv 
import os

# Load OpenAI API key from local environment 
load_dotenv("api.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

# Set up LLM client
llm_client = LLM(api_key=openai_api_key,
                 max_workers=30)

# Set up Scraper 
scraper = PFDScraper(
    category="suicide",
    date_from="2020-01-10", date_to="2020-03-11",
    llm = llm_client,
    llm_fallback=True)

# Scrape!
scraper.scrape_reports()
scraper.reports
# Out:
# INFO:pfd_toolkit.scraper:Total collected report links: 12
# Scraping reports: 100%|██████████| 12/12 [00:01<00:00,  9.65it/s]
# LLM fallback (parallel processing): 100%|██████████| 12/12 [00:44<00:00,  3.71s/it]
# CPU times: user 6.49 s, sys: 577 ms, total: 7.07 s
# Wall time: 51.6 s
#                                                   URL         ID        Date  \
# 0   https://www.judiciary.uk/prevention-of-future-...  2020-0052  2020-03-03
# 1   https://www.judiciary.uk/prevention-of-future-...  2020-0050  2020-03-03
# 4   https://www.judiciary.uk/prevention-of-future-...  2020-0043  2020-02-25
# 8   https://www.judiciary.uk/prevention-of-future-...  2020-0041  2020-02-21
# 2   https://www.judiciary.uk/prevention-of-future-...  2020-0027  2020-02-17
# 3   https://www.judiciary.uk/prevention-of-future-...  2020-0026  2020-02-11
# 5   https://www.judiciary.uk/prevention-of-future-...  2020-0008  2020-01-20
# 6   https://www.judiciary.uk/prevention-of-future-...  2020-0025  2020-01-20
# 9   https://www.judiciary.uk/prevention-of-future-...  2020-0010  2020-01-14
# 7   https://www.judiciary.uk/prevention-of-future-...  2020-0007  2020-01-10
# 10  https://www.judiciary.uk/prevention-of-future-...  2020-0005  2020-01-10
# 11  https://www.judiciary.uk/prevention-of-future-...  2019-0461  2019-12-10
#
#                                           CoronerName                    Area  \
# 0                                       Nadia Persaud             East London
# 1                                        Alison Mutch        Manchester South
# 4                            Veronica Hamilton-Deeley       Brighton and Hove
# 8                                         Simon Burge     Hampshire (Central)
# 2   Caroline Beasley-Murray, senior coroner, for t...                   Essex
# 3                                    Bridget Dolan QC             West Sussex
# 5                                       Graeme Hughes     South Wales Central
# 6                                     Andrew Bridgman      Manchester (South)
# 9                                        Andrew Haigh   Staffordshire (South)
# 7                                    Oliver Longstaff   West Yorkshire (West)
# 10                                   Oliver Longstaff   West Yorkshire (West)
# 11                                     Georgina Gibbs  South Yorkshire (East)
#
#                                              Receiver  \
# 0   Professor Oliver Shanley, Interim Chief Execut...
# 1                                Department of Health
# 4                                       Sussex Police
# 8   Chief Executive - Central and North West Londo...
# 2                                         NHS England
# 3   The Chief Executive, the Sussex Community NHS ...
# 5   The Chief Constable of South Wales Police & Th...
# 6   Ms Claire Molloy, Chief Executive, Pennine Car...
# 9                                        HMP Dovegate
# 7                  Kirklees Council\nHighways England
# 10        Bradford District Care NHS Foundation Trust
# 11  1. THE GOVERNOR OF HMP LINDHOLME\n2. HM INSPEC...
#
#                               InvestigationAndInquest  \
# 0   On the 23rd October 2019 I commenced an invest...
# 1   On 22nd July 2019, I commenced an investigatio...
# 4   On 9th October 2019 I commenced an investigati...
# 8   On 27th January 2020 I commenced an investigat...
# 2   On 3 January 2020 I commenced an investigation...
# 3   On 05 November 2019 I commenced an investigati...
# 5   On 04/04/2019 I commenced an investigation int...
# 6   On 24.05.18 an investigation was commenced int...
# 9   On 1st October 2018 I commenced an investigati...
# 7   On 17th September 2018 I commenced an investig...
# 10  On 14th March 2018, I commenced an investigati...
# 11  1. On 18th October 2019 I commenced an investi...
#
#                                  CircumstancesOfDeath  \
# 0       See narrative conclusion in box 3 for detail.
# 1   On 20th July Shaun Lea Turner was found unresp...
# 4                               See Record of Inquest
# 8   Mr Goldstraw was found hanging in cell B3-03 a...
# 2   Joseph James Gingell had suffered from mental ...
# 3   On 9 August 2109 Gemma Azhar had self-referred...
# 5   SWP officers attended room 161 at the Village ...
# 6   About 4 years prior, Samantha suffered an epis...
# 9   Marlon Roy Watson was a serving prisoner at HM...
# 7   On 12th September 2018, Mr Wajid was observed ...
# 10  At the time of his death, Mr Naylor was a pati...
# 11  1. Daniel Akam had some history of depression ...
#
#                                      MattersOfConcern
# 0   The matter of concern during the course of the...
# 1   During the course of the inquest the evidence ...
# 4   During the course of the inquest the evidence ...
# 8   The MATTERS OF CONCERNS are as follows:\n\nA. ...
# 2   During the course of the inquest the evidence ...
# 3   The MATTERS OF CONCERNS are as follows: Those ...
# 5   During the course of the inquest the evidence ...
# 6   During the course of the inquest the evidence ...
# 9   1. At the inquest there was a concern that mem...
# 7   During the course of the inquest the evidence ...
# 10  During the course of the inquest the evidence ...
# 11  During the course of the inquest the evidence ...

# %% [markdown]
# Between them, `LLM` and `PFDScraper` contain quite a few configurable parameters. Here are all of them with their default values:

# %%
from pfd_toolkit import PFDScraper, LLM

llm = LLM(
    api_key=None, # ...API key for LLM client (e.g. OpenAI),
    model="gpt-4.1-mini", # ...name of LLM model
    base_url=None, # ...if not using OpenAI, allow the user to point at alternative API (e.g. Gemini, Ollama)
    max_workers=1 # ...to enable LLM parallel API requests
)

scraper = PFDScraper(
    llm=None, # ...specify LLM client
    category='all', # ...category as given on judiciary.uk
    date_from="2000-01-01", date_to="2030-01-01", # ...date range for scraping
    max_workers=10, # ...parallelisation for CPU-bound tasks
    max_requests=5, # ...parallelisation for HTTP-bound tasks
    delay_range=(1, 2), # ...delay range between 1 and 2 seconds to mimic human browsing
    timeout=60, # ...60 second timeout for any individual scraping activity
    include_url=True, # ...whether to include 
    # (`include_` params for all other sections)
    verbose=False
)

# %% [markdown]
# ### Topping up reports
#
# Occassionaly, we might run the scraper once and want to 'top up' our reports as new ones are published. It would be a pain to run the entire scraper again, so we've included a `top_up()` method that scans for any new reports not part of our original dataframe, and seeks to add them.
#
# It uses the exact same configurations as the `scrape_reports()` methods (i.e. both inherit from the `PFDScraper` class).

# %%
scraper.top_up(date_to="2020-04-11") # ..add a month to the end date; look for new reports!
# Out:
# INFO:pfd_toolkit.scraper:Attempting to 'top up' the existing reports with new data.
# INFO:pfd_toolkit.scraper:Total collected report links: 22
# INFO:pfd_toolkit.scraper:Top-up: 10 new report(s) found; 12 duplicate(s) which won't be added
# Topping up reports: 100%|██████████| 10/10 [00:01<00:00,  9.61it/s]
#                                                   URL         ID        Date  \
# 12  https://www.judiciary.uk/prevention-of-future-...  2020-0077  2020-03-24
# 13  https://www.judiciary.uk/prevention-of-future-...  2020-0076  2020-03-24
# 14  https://www.judiciary.uk/prevention-of-future-...  2020-0074  2020-03-23
# 16  https://www.judiciary.uk/prevention-of-future-...  2020-0071  2020-03-16
# 18  https://www.judiciary.uk/prevention-of-future-...  2020-0064  2020-03-12
# 19  https://www.judiciary.uk/prevention-of-future-...  2020-0058  2020-03-09
# 20  https://www.judiciary.uk/prevention-of-future-...  2020-0056  2020-03-06
# 0   https://www.judiciary.uk/prevention-of-future-...  2020-0052  2020-03-03
# 1   https://www.judiciary.uk/prevention-of-future-...  2020-0050  2020-03-03
# 2   https://www.judiciary.uk/prevention-of-future-...  2020-0043  2020-02-25
# 3   https://www.judiciary.uk/prevention-of-future-...  2020-0041  2020-02-21
# 17  https://www.judiciary.uk/prevention-of-future-...  2020-0068  2020-02-21
# 4   https://www.judiciary.uk/prevention-of-future-...  2020-0027  2020-02-17
# 5   https://www.judiciary.uk/prevention-of-future-...  2020-0026  2020-02-11
# 21  https://www.judiciary.uk/prevention-of-future-...  2020-0055  2020-02-10
# 7   https://www.judiciary.uk/prevention-of-future-...  2020-0025  2020-01-20
# 6   https://www.judiciary.uk/prevention-of-future-...  2020-0008  2020-01-20
# 15  https://www.judiciary.uk/prevention-of-future-...  2020-0072  2020-01-15
# 8   https://www.judiciary.uk/prevention-of-future-...  2020-0010  2020-01-14
# 10  https://www.judiciary.uk/prevention-of-future-...  2020-0005  2020-01-10
# 9   https://www.judiciary.uk/prevention-of-future-...  2020-0007  2020-01-10
# 11  https://www.judiciary.uk/prevention-of-future-...  2019-0461  2019-12-10
#
#                                           CoronerName  \
# 12                                      Andrew Walker
# 13                                  Geoffrey Sullivan
# 14                                 Nicholas Rheinberg
# 16                                 Penelope Schofield
# 18                                   Geraint Williams
# 19                                       Fiona Wilcox
# 20                                      Andre Rebello
# 0                                       Nadia Persaud
# 1                                        Alison Mutch
# 2                            Veronica Hamilton-Deeley
# 3                                         Simon Burge
# 17                                Jacqueline Devonish
# 4   Caroline Beasley-Murray, senior coroner, for t...
# 5                                    Bridget Dolan QC
# 21                                      Andrew Harris
# 7                                     Andrew Bridgman
# 6                                       Graeme Hughes
# 15                                        Rachel Syed
# 8                                        Andrew Haigh
# 10                                   Oliver Longstaff
# 9                                    Oliver Longstaff
# 11                                     Georgina Gibbs
#
#                         Area  \
# 12            London (North)
# 13             Hertfordshire
# 14  Exeter and Greater Devon
# 16               West Sussex
# 18       South Wales Central
# 19       London Inner (West)
# 20  Liverpool and the Wirral
# 0                East London
# 1           Manchester South
# 2          Brighton and Hove
# 3        Hampshire (Central)
# 17              London South
# 4                      Essex
# 5                West Sussex
# 21        London Inner South
# 7         Manchester (South)
# 6        South Wales Central
# 15           Manchester West
# 8      Staffordshire (South)
# 10     West Yorkshire (West)
# 9      West Yorkshire (West)
# 11    South Yorkshire (East)
#
#                                              Receiver  \
# 12  Ministerial Correspondence and Public Enquirie...
# 13                                     N/A: Not found
# 14  1. Devon Partnership NHS Trust as lead for the...
# 16  Ms Samantha Allen Chief Executive Sussex Partn...
# 18                        Cardiff & Vale NHS Trust 1.
# 19                                     N/A: Not found
# 20                                              HMPPS
# 0   Professor Oliver Shanley, Interim Chief Execut...
# 1                                Department of Health
# 2                                       Sussex Police
# 3   Chief Executive - Central and North West Londo...
# 17  1. Matthew Trainer, Chief Executive Oxleas NHS...
# 4                                         NHS England
# 5   The Chief Executive, the Sussex Community NHS ...
# 21                                     N/A: Not found
# 7   Ms Claire Molloy, Chief Executive, Pennine Car...
# 6   The Chief Constable of South Wales Police & Th...
# 15                                     N/A: Not found
# 8                                        HMP Dovegate
# 10        Bradford District Care NHS Foundation Trust
# 9                  Kirklees Council\nHighways England
# 11  1. THE GOVERNOR OF HMP LINDHOLME\n2. HM INSPEC...
#
#                               InvestigationAndInquest  \
# 12  On the 21st day of October 2019 I opened an in...
# 13                                     N/A: Not found
# 14  On 27th April 2017 an investigation into the d...
# 16  On 6th November 2018 I commenced an investigat...
# 18  On 26th October 2017 I commenced an investigat...
# 19                                     N/A: Not found
# 20  On 11/10/2017 I commenced an investigation int...
# 0   On the 23rd October 2019 I commenced an invest...
# 1   On 22nd July 2019, I commenced an investigatio...
# 2   On 9th October 2019 I commenced an investigati...
# 3   On 27th January 2020 I commenced an investigat...
# 17  On 17 October 2019 I commenced an investigatio...
# 4   On 3 January 2020 I commenced an investigation...
# 5   On 05 November 2019 I commenced an investigati...
# 21                                     N/A: Not found
# 7   On 24.05.18 an investigation was commenced int...
# 6   On 04/04/2019 I commenced an investigation int...
# 15                                     N/A: Not found
# 8   On 1st October 2018 I commenced an investigati...
# 10  On 14th March 2018, I commenced an investigati...
# 9   On 17th September 2018 I commenced an investig...
# 11  1. On 18th October 2019 I commenced an investi...
#
#                                  CircumstancesOfDeath  \
# 12  On the Second of October 2019 Simon Anthony De...
# 13                                     N/A: Not found
# 14  Lewis Francis whilst acutely psychotic stabbed...
# 16                                     N/A: Not found
# 18  These were recorded as:- Ian Weeks was remande...
# 19                                     N/A: Not found
# 20  The Jury found: During admission to 68 Hornby ...
# 0       See narrative conclusion in box 3 for detail.
# 1   On 20th July Shaun Lea Turner was found unresp...
# 2                               See Record of Inquest
# 3   Mr Goldstraw was found hanging in cell B3-03 a...
# 17  On 12 August 2019 Billy Jenkins was found hang...
# 4   Joseph James Gingell had suffered from mental ...
# 5   On 9 August 2109 Gemma Azhar had self-referred...
# 21                                     N/A: Not found
# 7   About 4 years prior, Samantha suffered an epis...
# 6   SWP officers attended room 161 at the Village ...
# 15                                     N/A: Not found
# 8   Marlon Roy Watson was a serving prisoner at HM...
# 10  At the time of his death, Mr Naylor was a pati...
# 9   On 12th September 2018, Mr Wajid was observed ...
# 11  1. Daniel Akam had some history of depression ...
#
#                                      MattersOfConcern
# 12  During the course of the inquest the evidence ...
# 13                                     N/A: Not found
# 14  During the course of the inquest the evidence ...
# 16  During the course of the inquest the evidence ...
# 18  During the course of the inquest the evidence ...
# 19                                     N/A: Not found
# 20  The MATTERS OF CONCERNS are as follows: (brief...
# 0   The matter of concern during the course of the...
# 1   During the course of the inquest the evidence ...
# 2   During the course of the inquest the evidence ...
# 3   The MATTERS OF CONCERNS are as follows:\n\nA. ...
# 17  During the course of the inquest the evidence ...
# 4   During the course of the inquest the evidence ...
# 5   The MATTERS OF CONCERNS are as follows: Those ...
# 21                                     N/A: Not found
# 7   During the course of the inquest the evidence ...
# 6   During the course of the inquest the evidence ...
# 15                                     N/A: Not found
# 8   1. At the inquest there was a concern that mem...
# 10  During the course of the inquest the evidence ...
# 9   During the course of the inquest the evidence ...
# 11  During the course of the inquest the evidence ...

# %% [markdown]
# Incidentally, running `top_up()` is also how the dataset contained within `load_data()` gets updated each week, under the hood. All using PFD Toolkit methods!

# %% [markdown]
# ### Cleaning reports
#
# PFD Reports have a lot of spelling & grammatical errors. Additionally, the Concerns section tends to have a lot of boilerplate text, which differs slightly between reports (meaning that regex can't help us here).
#
# On top of this, the way that coroner names are formatted can also differ from report to report, making it difficult to filter for specific coroner.
#
# We can use an LLM to fix all of these issues...

# %%
# %%time

from pfd_toolkit import Cleaner, LLM

# Set up LLM client
llm_client = LLM(api_key=openai_api_key, 
                 max_workers=30)

# Run cleaner
cleaner = Cleaner(
    llm=llm_client,
    reports=scraper.reports)

cleaned_reports = cleaner.clean_reports()
cleaned_reports
# Out:
# Processing Fields:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing Fields: 100%|██████████| 6/6 [00:42<00:00,  7.04s/it]
# CPU times: user 1.92 s, sys: 158 ms, total: 2.08 s
# Wall time: 42.2 s
#                                                   URL         ID        Date  \
# 12  https://www.judiciary.uk/prevention-of-future-...  2020-0077  2020-03-24
# 13  https://www.judiciary.uk/prevention-of-future-...  2020-0076  2020-03-24
# 14  https://www.judiciary.uk/prevention-of-future-...  2020-0074  2020-03-23
# 16  https://www.judiciary.uk/prevention-of-future-...  2020-0071  2020-03-16
# 18  https://www.judiciary.uk/prevention-of-future-...  2020-0064  2020-03-12
# 19  https://www.judiciary.uk/prevention-of-future-...  2020-0058  2020-03-09
# 20  https://www.judiciary.uk/prevention-of-future-...  2020-0056  2020-03-06
# 0   https://www.judiciary.uk/prevention-of-future-...  2020-0052  2020-03-03
# 1   https://www.judiciary.uk/prevention-of-future-...  2020-0050  2020-03-03
# 2   https://www.judiciary.uk/prevention-of-future-...  2020-0043  2020-02-25
# 3   https://www.judiciary.uk/prevention-of-future-...  2020-0041  2020-02-21
# 17  https://www.judiciary.uk/prevention-of-future-...  2020-0068  2020-02-21
# 4   https://www.judiciary.uk/prevention-of-future-...  2020-0027  2020-02-17
# 5   https://www.judiciary.uk/prevention-of-future-...  2020-0026  2020-02-11
# 21  https://www.judiciary.uk/prevention-of-future-...  2020-0055  2020-02-10
# 7   https://www.judiciary.uk/prevention-of-future-...  2020-0025  2020-01-20
# 6   https://www.judiciary.uk/prevention-of-future-...  2020-0008  2020-01-20
# 15  https://www.judiciary.uk/prevention-of-future-...  2020-0072  2020-01-15
# 8   https://www.judiciary.uk/prevention-of-future-...  2020-0010  2020-01-14
# 10  https://www.judiciary.uk/prevention-of-future-...  2020-0005  2020-01-10
# 9   https://www.judiciary.uk/prevention-of-future-...  2020-0007  2020-01-10
# 11  https://www.judiciary.uk/prevention-of-future-...  2019-0461  2019-12-10
#
#            CoronerName                      Area  \
# 12           A. Walker              London North
# 13         G. Sullivan             Hertfordshire
# 14        N. Rheinberg  Exeter and Greater Devon
# 16        P. Schofield               West Sussex
# 18         G. Williams       South Wales Central
# 19           F. Wilcox         London Inner West
# 20          A. Rebello  Liverpool and the Wirral
# 0           N. Persaud               East London
# 1             A. Mutch          Manchester South
# 2   V. Hamilton-Deeley         Brighton and Hove
# 3             S. Burge         Hampshire Central
# 17         J. Devonish              London South
# 4    C. Beasley-Murray                     Essex
# 5             B. Dolan               West Sussex
# 21           A. Harris        London Inner South
# 7          A. Bridgman          Manchester South
# 6            G. Hughes       South Wales Central
# 15             R. Syed           Manchester West
# 8             A. Haigh     Staffordshire (South)
# 10        O. Longstaff     West Yorkshire (West)
# 9         O. Longstaff     West Yorkshire (West)
# 11            G. Gibbs    South Yorkshire (East)
#
#                                              Receiver  \
# 12  Ministerial Correspondence and Public Enquirie...
# 13                                     N/A: Not found
# 14  Devon Partnership NHS Trust as lead for the So...
# 16  Ms Samantha Allen Chief Executive Sussex Partn...
# 18                           Cardiff & Vale NHS Trust
# 19                                     N/A: Not found
# 20                                              HMPPS
# 0   Professor Oliver Shanley, Interim Chief Execut...
# 1                                Department of Health
# 2                                       Sussex Police
# 3   Chief Executive - Central and North West Londo...
# 17  Matthew Trainer Chief Executive Oxleas NHS Fou...
# 4                                         NHS England
# 5   The Chief Executive; Sussex Community NHS Foun...
# 21                                     N/A: Not found
# 7   Ms Claire Molloy, Chief Executive, Pennine Car...
# 6   The Chief Constable of South Wales Police; The...
# 15                                     N/A: Not found
# 8                                        HMP Dovegate
# 10        Bradford District Care NHS Foundation Trust
# 9                  Kirklees Council; Highways England
# 11  The Governor of HMP Lindholme; HM Inspector of...
#
#                               InvestigationAndInquest  \
# 12  On the 21st day of October 2019 I opened an in...
# 13                                     N/A: Not found
# 14  On 27 April 2017 an investigation into the dea...
# 16  On 6 November 2018 I commenced an investigatio...
# 18  On 26 October 2017 I commenced an investigatio...
# 19                                     N/A: Not found
# 20  On 11 October 2017 I commenced an investigatio...
# 0   On the 23rd October 2019 I commenced an invest...
# 1   On 22 July 2019, I commenced an investigation ...
# 2   On 9 October 2019 I commenced an investigation...
# 3   On 27 January 2020 I commenced an investigatio...
# 17  On 17 October 2019 I commenced an investigatio...
# 4   On 3 January 2020 I commenced an investigation...
# 5   On 5 November 2019 I commenced an investigatio...
# 21                                     N/A: Not found
# 7   On 24 May 2018 an investigation was commenced ...
# 6   On 4th April 2019 I commenced an investigation...
# 15                                     N/A: Not found
# 8   On 1 October 2018 I commenced an investigation...
# 10  On 14 March 2018, I commenced an investigation...
# 9   On 17 September 2018 I commenced an investigat...
# 11  On 18 October 2019 I commenced an investigatio...
#
#                                  CircumstancesOfDeath  \
# 12  On the second of October two thousand and nine...
# 13                                     N/A: Not found
# 14  Lewis Francis whilst acutely psychotic stabbed...
# 16                                     N/A: Not found
# 18  Ian Weeks was remanded into custody at HMP Car...
# 19                                     N/A: Not found
# 20  During admission to 68 Hornby Road, Liverpool ...
# 0       See narrative conclusion in box 3 for detail.
# 1   On 20 July Shaun Lea Turner was found unrespon...
# 2                               See Record of Inquest
# 3   Mr Goldstraw was found hanging in cell B3-03 a...
# 17  On 12 August 2019 Billy Jenkins was found hang...
# 4   Joseph James Gingell had suffered from mental ...
# 5   On the evening of the 31st October 2019 Gemma ...
# 21                                     N/A: Not found
# 7   About four years prior, Samantha suffered an e...
# 6   SWP officers attended room 161 at the Village ...
# 15                                     N/A: Not found
# 8   Marlon Roy Watson was a serving prisoner at HM...
# 10  At the time of his death, Mr Naylor was a pati...
# 9   On 12 September 2018, Mr Wajid was observed by...
# 11  Daniel Akam had some history of depression and...
#
#                                      MattersOfConcern
# 12  There are no arrangements or guidance concerni...
# 13                                     N/A: Not found
# 14  At present there is no mechanism for the ready...
# 16  1. Mr Ashley's care and treatment plan was not...
# 18  Although it was recorded on System 1 that Mr W...
# 19                                     N/A: Not found
# 20  During the course of evidence it became appare...
# 0   A GP made a referral to the mental health team...
# 1   During the course of the inquest, evidence was...
# 2   Mr Reilly visited Beachy Head on the 1st of Oc...
# 3   A. The computer system used by CNWL is known a...
# 17  (1) The findings of the internal investigation...
# 4   (1) The drugs found in Mr Gingell's system are...
# 5   Those in need of the TTT service and support m...
# 21                                     N/A: Not found
# 7   The matter of concern is that despite the conc...
# 6   (1) The inquest focused upon the response of t...
# 15                                     N/A: Not found
# 8   At the inquest there was a concern that member...
# 10  The jury formally recorded their opinion as pa...
# 9   Scammonden Bridge is a locally notorious locat...
# 11  Failure to carry out ACCT observations recorde...

# %% [markdown]
# Notice, for example, how the coroner name has been reformatted around common denominators: intiial of first name and last name. Other changes likely aren't visible without inspecting the dataframe in more detail.

# %% [markdown]
# ### What comes next
#
# Version 0.1.27 of PFD Toolkit is still an early build. For future versions (in 0.1.xx), the focus is on improving the success of LLM-scraping. Version 0.2.xx will come with a Categorisation module, allowing users to provide themes and sub-themes for custom data curation.
