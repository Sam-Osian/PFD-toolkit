# %% [markdown]
# ## Loading the PFD reports
#
# The user can load PFD reports without running the scraping module, as the complete dataset is bundled along with the package.
#
# What currently works:
#
# * Importing all PFD reports
# * Filtering based on date
#
# What still needs to be developed:
#
# * Filtering based on category
# * Currently, the stored reports are HTML+PDF scraped only (not LLM scraped). We will change to only LLM scraped.
# * (Optional -- not sure about this yet) A toggle for whether the user wants to import cleaned or uncleaned versions of the report text

# %% [markdown]
# #### Get all reports

# %%
from pfd_toolkit import load_reports

reports = load_reports()
reports
# Out:
#                                                     URL         ID       Date  \
# 0     https://www.judiciary.uk/prevention-of-future-...  2025-0080 2025-12-17
# 1     https://www.judiciary.uk/prevention-of-future-...  2025-0236 2025-05-21
# 2     https://www.judiciary.uk/prevention-of-future-...  2025-0237 2025-05-21
# 3     https://www.judiciary.uk/prevention-of-future-...  2025-0238 2025-05-21
# 4     https://www.judiciary.uk/prevention-of-future-...  2025-0235 2025-05-20
# ...                                                 ...        ...        ...
# 5682  https://www.judiciary.uk/prevention-of-future-...  2013-0171 2013-08-01
# 5683  https://www.judiciary.uk/prevention-of-future-...  2013-0172 2013-08-01
# 5684  https://www.judiciary.uk/prevention-of-future-...  2013-0174 2013-07-30
# 5685  https://www.judiciary.uk/prevention-of-future-...  2013-0175 2013-07-30
# 5686  https://www.judiciary.uk/prevention-of-future-...  2013-0308 2013-02-21
#
#                                             CoronerName  \
# 0                                        Laurinda Bower
# 1                                        Kate Robertson
# 2                                            Guy Davies
# 3                                     Caroline Saunders
# 4                                           Louise Hunt
# ...                                                 ...
# 5682                                   David Hinchcliff
# 5683                                      M A Beresford
# 5684  also under a duty to send the Chief Coroner a ...
# 5685  also under a duty to send the Chief Coroner a ...
# 5686                                        Lisa Hashmi
#
#                                      Area  \
# 0     Nottingham City and Nottinghamshire
# 1                        North West Wales
# 2        Cornwall and the Isles of Scilly
# 3                                   Gwent
# 4                 Birmingham and Solihull
# ...                                   ...
# 5682                West Yorkshire (East)
# 5683               South Yorkshire (East)
# 5684                          West Sussex
# 5685                          West Sussex
# 5686                     Manchester North
#
#                                                Receiver  \
# 0                                    HMP Lowdham Grange
# 1     Betsi Cadwaladr University Health Board (BCUHB) 1
# 2     Interim Chief Executive NHS University Hospita...
# 3     The Chief Executive of Aneurin Bevan Universit...
# 4                          West Midlands Fire Service 1
# ...                                                 ...
# 5682                                      Saga Homecare
# 5683  to the Lord Chancellor and all the other prope...
# 5684                                       to the Chief
# 5685                                       to the Chief
# 5686                                     N/A: Not found
#
#                                 InvestigationAndInquest  \
# 0                                        N/A: Not found
# 1     On 20 May 2024 I commenced an investigation in...
# 2     On 30 July 2024 I commenced an investigation i...
# 3     On 28/2/2024 an investigation was opened touch...
# 4     On 5 February 2024 I commenced an investigatio...
# ...                                                 ...
# 5682                                     N/A: Not found
# 5683                                     N/A: Not found
# 5684                                     N/A: Not found
# 5685                                     N/A: Not found
# 5686                                     N/A: Not found
#
#                                    CircumstancesOfDeath  \
# 0     Anthony Binfield died as a result of ligature ...
# 1     The circumstances of the death are as follows ...
# 2     Dave opted for an elective surgical procedure ...
# 3     Marina Waldron was admitted to hospital on 17/...
# 4     Mr Brown was found hanging [REDACTED] at his h...
# ...                                                 ...
# 5682                                     N/A: Not found
# 5683                                     N/A: Not found
# 5684                                     N/A: Not found
# 5685                                     N/A: Not found
# 5686                                     N/A: Not found
#
#                                        MattersOfConcern
# 0     During the course of the investigation my inqu...
# 1     During the course of the inquest, the evidence...
# 2     During the course of the inquest the evidence ...
# 3     The MATTERS OF CONCERN are as follows: - Durin...
# 4     During the course of the inquest the evidence ...
# ...                                                 ...
# 5682                                     N/A: Not found
# 5683                                     N/A: Not found
# 5684  : (1) On admission to hospital and at pre-asse...
# 5685  : (a)The need to carry out a risk assessment w...
# 5686                                     N/A: Not found
#
# [5687 rows x 9 columns]

# %% [markdown]
# #### See how many reports have been released last year (2024)

# %%
reports = load_reports(
    start_date="2024-01-01",
    end_date="2024-12-31")

len(reports)
# Out:
# 687
