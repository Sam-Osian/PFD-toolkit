# %% [markdown]
# # Feature extraction DEMO
#
# *"Can we extract age from PFD reports?"*
#
# **Context:** There is no age field in PFD reports. However, many coroners note age in the investigation or circumstances sections of the report. This demo investigates whether age can be extracted from these reports using PFD Toolkit's `Extractor` class.

# %%
from pfd_toolkit import load_reports, LLM, Extractor
from dotenv import load_dotenv
import os
from pydantic import BaseModel

# Load reports sample
reports = load_reports(n_reports=150)

# Load OpenAI API key
load_dotenv("api.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

# Initialise LLM client
llm_client = LLM(api_key=openai_api_key, max_workers=30)

# Initialise Pydantic model
class DemoFeatures(BaseModel):
    age: int
    ethnicity: str

# Initialise extraction instructions
feature_instructions = {
    "age": "Age of the deceased",
    "ethnicity": "Ethnicity of the deceased",
}


extractor = Extractor(
    llm=llm_client,
    feature_model=DemoFeatures,
    feature_instructions=feature_instructions,
    reports=reports,
    include_investigation=True,
    include_circumstances=True,
)

result_df = extractor.extract_features()
result_df
# Out:
# LLM: Extracting features: 100%|██████████| 150/150 [00:08<00:00, 16.96it/s]
#                                                    URL  ...       ethnicity
# 0    https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 1    https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 2    https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 3    https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 4    https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# ..                                                 ...  ...             ...
# 145  https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 146  https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 147  https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 148  https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
# 149  https://www.judiciary.uk/prevention-of-future-...  ...  N/A: Not found
#
# [150 rows x 11 columns]

# %%
result_df.to_csv('../data/age_extracted.csv')
