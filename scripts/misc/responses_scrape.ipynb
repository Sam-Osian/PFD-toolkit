# %%
from pfd_toolkit import load_reports, LLM, Scraper

# %%
reports = load_reports(start_date="2024-11-01", 
                       end_date="2024-11-15",
                       refresh=True)

print(f"{len(reports)} reports loaded.")
# Out:
# 38 reports loaded.

# %%
from dotenv import load_dotenv
import os

# Load OpenAI API key from local environment
load_dotenv("api.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

# Initialise LLM client
llm_client = LLM(api_key=openai_api_key, 
                 max_workers=30, 
                 model="gpt-4.1-mini",
                 seed=123, 
                 temperature=0, 
                 timeout=60)

# %%
scraper = Scraper(llm=llm_client)

responses = scraper.scrape_responses(reports=reports,
                                     verify_responses=True)

responses
# Out:
# Collecting response documents: 100%|██████████| 38/38 [00:50<00:00,  1.32s/it]
# Verifying that all documents are responses: 100%|██████████| 75/75 [00:25<00:00,  2.88it/s]
# Scraping response documents: 100%|██████████| 75/75 [00:47<00:00,  1.58it/s]
# INFO:pfd_toolkit.scraper.scraper:Skipping response at https://www.judiciary.uk/wp-content/uploads/2024/11/2024-0634-Response-from-Red-Bay-Boats-Limited.pdf from https://www.judiciary.uk/prevention-of-future-death-reports/emily-lewis-prevention-of-future-deaths-report/ (2024-0634) because no recipient matched provided list.
# INFO:pfd_toolkit.scraper.scraper:Skipping response at https://www.judiciary.uk/wp-content/uploads/2024/11/2024-0604-Response-from-NHS-England.pdf from https://www.judiciary.uk/prevention-of-future-death-reports/simon-boyd-prevention-of-future-deaths-report/ (2024-0604) because no recipient matched provided list.
#            id                                         parent_url  \
# 0   2024-0634  https://www.judiciary.uk/prevention-of-future-...
# 1   2024-0634  https://www.judiciary.uk/prevention-of-future-...
# 2   2024-0634  https://www.judiciary.uk/prevention-of-future-...
# 3   2024-0634  https://www.judiciary.uk/prevention-of-future-...
# 4   2024-0634  https://www.judiciary.uk/prevention-of-future-...
# ..        ...                                                ...
# 63  2024-0595  https://www.judiciary.uk/prevention-of-future-...
# 64  2024-0594  https://www.judiciary.uk/prevention-of-future-...
# 65  2024-0606  https://www.judiciary.uk/prevention-of-future-...
# 66  2024-0606  https://www.judiciary.uk/prevention-of-future-...
# 67  2024-0591  https://www.judiciary.uk/prevention-of-future-...
#
#                                          response_url  \
# 0   https://www.judiciary.uk/wp-content/uploads/20...
# 1   https://www.judiciary.uk/wp-content/uploads/20...
# 2   https://www.judiciary.uk/wp-content/uploads/20...
# 3   https://www.judiciary.uk/wp-content/uploads/20...
# 4   https://www.judiciary.uk/wp-content/uploads/20...
# ..                                                ...
# 63  https://www.judiciary.uk/wp-content/uploads/20...
# 64  https://www.judiciary.uk/wp-content/uploads/20...
# 65  https://www.judiciary.uk/wp-content/uploads/20...
# 66  https://www.judiciary.uk/wp-content/uploads/20...
# 67  https://www.judiciary.uk/wp-content/uploads/20...
#
#                                            respondent  \
# 0                     UK Harbour Masters’ Association
# 1                                UK Major Ports Group
# 2                                 Transport Secretary
# 3                           British Ports Association
# 4                          Royal Yachting Association
# ..                                                ...
# 63  Safeguarding Adults Team, East Riding of Yorks...
# 64  Director of Highways and Operations Oxfordshir...
# 65  Secretary of State for Health and Social Care,...
# 66                       Chief Executive, NHS England
# 67  University Hospitals Birmingham NHS Foundation...
#
#                                              response
# 0   On behalf of UKHMA, I am grateful for you iden...
# 1   We will support any guidance and actions sugge...
# 2   In response to the MAIB recommendations raised...
# 3   I can confirm that the British Ports Associati...
# 4   Thank you for your communication of 18th Novem...
# ..                                                ...
# 63  It is usual practice that the local authority ...
# 64  Thank you for your letter dated 4th November 2...
# 65  I understand your concerns about a bed on the ...
# 66  Thank you for your Report to Prevent Future De...
# 67  I am writing in response to the Regulation 28 ...
#
# [68 rows x 5 columns]

# %%
responses.iloc[0]
# Out:
# id                                                      2024-0634
# parent_url      https://www.judiciary.uk/prevention-of-future-...
# response_url    https://www.judiciary.uk/wp-content/uploads/20...
# respondent                        UK Harbour Masters’ Association
# response        On behalf of UKHMA, I am grateful for you iden...
# Name: 0, dtype: object
